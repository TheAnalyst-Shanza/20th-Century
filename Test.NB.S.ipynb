# %%
1+1
# Out:
# 2

# %%
# %cd "C:/Users/User/Downloads/20th-Century"
# !dir
# Out:
# C:\Users\User\Downloads\20th-Century
#  Volume in drive C is Windows
#  Volume Serial Number is A892-6932
#
#  Directory of C:\Users\User\Downloads\20th-Century
#
# 11/04/2025  01:02 PM    <DIR>          .
# 11/04/2025  01:02 PM    <DIR>          ..
# 11/04/2025  01:02 PM    <DIR>          .ipynb_checkpoints
# 11/04/2025  01:33 AM                 2 README.md
# 11/04/2025  01:01 PM               967 Test.NB.S.ipynb
#                2 File(s)            969 bytes
#                3 Dir(s)  1,829,443,190,784 bytes free

# %%
# %cd "C:/Users/User/Downloads/20th-Century"
# !git status
# Out:
# C:\Users\User\Downloads\20th-Century
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.ipynb_checkpoints/
# 	Test.NB.S.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add "Test.NB.S.ipynb"
# !git commit -m "Add test notebook"
# !git status
# Out:
# ...
# [main 580d758] Add test notebook
#  1 file changed, 85 insertions(+)
#  create mode 100644 Test.NB.S.ipynb
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.ipynb_checkpoints/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push origin main
# Out:
# To github.com:TheAnalyst-Shanza/20th-Century.git
#    7940b29..580d758  main -> main
